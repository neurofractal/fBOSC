# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("white")
import pandas as pd
from scipy import stats
from matplotlib.pyplot import figure

# %%
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})

# %%
df = pd.read_csv('MEG_source_localised.csv')
df.head()
# Out:
#    error_both condition
# 0    0.035943     fixed
# 1    0.028008     fixed
# 2    0.045254     fixed
# 3    0.031433     fixed
# 4    0.035256     fixed

# %%
ax = sns.violinplot(x="condition", y="error_both",
                    palette=sns.color_palette(['lightgray','lightgray','lightgray']),
                    linewidth=2.5,cut=0,inner='quartile', data=df)
#ax = sns.boxplot(x="group", y="peak_freq",palette=sns.color_palette(['lightgray','lightgray']), data=df)
ax = sns.swarmplot(x="condition", y="error_both",
                   palette=sns.color_palette(['#ff5c04','#c8588e','#045cff']),alpha=0.7,size=0.5, data=df)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.set_ylabel("Error",fontsize=25,fontname="Arial")
ax.set_xlabel("",fontsize=25,fontname="Arial")
#ax.set_xticklabels(['Control','Visual\nSnow'])
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
fig = ax.get_figure()
fig.show()
fig.savefig('MEG_source_localised.png', bbox_inches='tight',dpi=600)
# Out:
# /Users/rseymoue/miniconda3/envs/py35/lib/python3.5/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
df = pd.read_csv('OPMMEG.csv')

# %%
ax = sns.violinplot(x="condition", y="error_both",
                    palette=sns.color_palette(['lightgray','lightgray','lightgray']),
                    linewidth=2.5,cut=1,inner='quartile', data=df)
#ax = sns.boxplot(x="group", y="peak_freq",palette=sns.color_palette(['lightgray','lightgray']), data=df)
ax = sns.swarmplot(x="condition", y="error_both",
                   palette=sns.color_palette(['#ff5c04','#c8588e','#045cff']),alpha=0.7,size=5, data=df)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.set_ylabel("Error",fontsize=25,fontname="Arial")
ax.set_xlabel("",fontsize=25,fontname="Arial")
#ax.set_xticklabels(['Control','Visual\nSnow'])
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
fig = ax.get_figure()
fig.show()
#fig.savefig('MEG_source_localised.png', bbox_inches='tight',dpi=600)
# Out:
# /Users/rseymoue/miniconda3/envs/py35/lib/python3.5/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
df = pd.read_csv('ECOG.csv')

# %%
ax = sns.violinplot(x="condition", y="error_both",
                    palette=sns.color_palette(['lightgray','lightgray','lightgray']),
                    linewidth=2.5,cut=1,inner='quartile', data=df)
#ax = sns.boxplot(x="group", y="peak_freq",palette=sns.color_palette(['lightgray','lightgray']), data=df)
ax = sns.swarmplot(x="condition", y="error_both",
                   palette=sns.color_palette(['#ff5c04','#c8588e','#045cff']),alpha=0.7,size=1, data=df)
ax.tick_params(axis='both', which='major', labelsize=18)
ax.set_ylabel("Error",fontsize=25,fontname="Arial")
ax.set_xlabel("",fontsize=25,fontname="Arial")
#ax.set_xticklabels(['Control','Visual\nSnow'])
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
fig = ax.get_figure()
fig.show()
fig.savefig('ECOG.png', bbox_inches='tight',dpi=600)
# Out:
# /Users/rseymoue/miniconda3/envs/py35/lib/python3.5/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
